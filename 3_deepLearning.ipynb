# %% [markdown]
# # Downloading Libraries

# %%
! pip install nltk
! pip install vaderSentiment
! pip install pytrends
! pip install textblob
! pip install wordcloud
! pip install gensim
! pip install seaborn
! pip install TextBlob
! pip install joblib
# Out:
# Requirement already satisfied: nltk in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: vaderSentiment in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (3.3.2)
# Requirement already satisfied: requests in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from vaderSentiment) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from requests->vaderSentiment) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from requests->vaderSentiment) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from requests->vaderSentiment) (2023.11.17)
# Requirement already satisfied: pytrends in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (4.9.2)
# Requirement already satisfied: requests>=2.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pytrends) (2.31.0)
# Requirement already satisfied: pandas>=0.25 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pytrends) (2.0.3)
# Requirement already satisfied: lxml in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pytrends) (5.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2023.4)
# Requirement already satisfied: numpy>=1.20.3 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (1.23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from requests>=2.0->pytrends) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from requests>=2.0->pytrends) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from requests>=2.0->pytrends) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from requests>=2.0->pytrends) (2023.11.17)
# Requirement already satisfied: six>=1.5 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.16.0)
# Requirement already satisfied: textblob in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->textblob) (4.66.1)
# Requirement already satisfied: wordcloud in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from wordcloud) (1.23.2)
# Requirement already satisfied: pillow in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from wordcloud) (3.7.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->wordcloud) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib->wordcloud) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: gensim in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from gensim) (1.23.2)
# Requirement already satisfied: scipy>=1.7.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from gensim) (6.4.0)
# Requirement already satisfied: seaborn in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from seaborn) (1.23.2)
# Requirement already satisfied: pandas>=1.2 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from seaborn) (3.7.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: zipp>=3.1.0 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: TextBlob in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from TextBlob) (3.8.1)
# Requirement already satisfied: click in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->TextBlob) (8.1.7)
# Requirement already satisfied: joblib in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->TextBlob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->TextBlob) (2023.12.25)
# Requirement already satisfied: tqdm in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->TextBlob) (4.66.1)
# Requirement already satisfied: joblib in /Users/taimourabdulkarim/miniforge3/envs/mlp/lib/python3.8/site-packages (1.3.2)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('wordnet', quiet=True)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# # Importing Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Cleaned Data/reviews.csv')
df.head()
# Out:
#            listing_id reviewer_name  \
# 0             4326511         Laura
# 1  603032069621870277        Fatima
# 2             8629818        Andrew
# 3            25012636          Kate
# 4            12725143          Yvon
#
#                                             comments  \
# 0  Das Zimmer und das Bad waren sauber und komfor...
# 1                                        Bad service
# 2  In Paul's absence, Lucy and Jack were amazing ...
# 3  I used Nicholas’ room as a base whilst I was i...
# 4  You can’t go wrong with the townhouse. It has ...
#
#                                     cleaned_comments  polarity sentiment
# 0  da zimmer und da bad waren sauber und komforta...      -0.7  negative
# 1                                         bad servic      -0.7  negative
# 2  paul absenc luci jack amaz host brthe secret g...      -0.4  negative
# 3  use nicholas’ room base whilst properti busi f...      -0.8  negative
# 4  can’t go wrong townhous amen need place spotle...      -0.5  negative

# %% [markdown]
# # Date Preprocessing

# %%
df.isnull().sum()
# Out:
# listing_id            0
# reviewer_name        63
# comments             63
# cleaned_comments    209
# polarity            163
# sentiment           163
# dtype: int64

# %%
# Dropping the null values
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# listing_id          0
# reviewer_name       0
# comments            0
# cleaned_comments    0
# polarity            0
# sentiment           0
# dtype: int64

# %% [markdown]
# ## **<center><u>Assessment: Experimentations (using Deep Learning)</u></center>**

# %%
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    # Tokenize and remove stop words
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word.isalpha()
              and word not in stop_words]
    return " ".join(tokens)

# %%
# Apply preprocessing to cleaned comments
df['processed_comments'] = df['cleaned_comments'].apply(preprocess_text)

# %%
# Tokenize text
tokenizer = Tokenizer(num_words=500, oov_token="<OOV>")
tokenizer.fit_on_texts(df['processed_comments'])
sequences = tokenizer.texts_to_sequences(df['processed_comments'])

# %%
# Pad sequences
max_length = max(len(x) for x in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# %%
# Encode labels
labels = pd.get_dummies(df['sentiment']).values

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences, labels, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Embedding(5000, 128, input_length=max_length))
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(labels.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 708, 128)          640000
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 691587 (2.64 MB)
# Trainable params: 691587 (2.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1)

history = model.fit(X_train, y_train, epochs=100, batch_size=128,
                    validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 58/58 [==============================] - 148s 2s/step - loss: 1.0995 - accuracy: 0.3352 - val_loss: 1.0987 - val_accuracy: 0.3411
# Epoch 2/100
# 58/58 [==============================] - 136s 2s/step - loss: 1.0989 - accuracy: 0.3461 - val_loss: 1.0986 - val_accuracy: 0.3411
# Epoch 3/100
# 58/58 [==============================] - 139s 2s/step - loss: 1.0986 - accuracy: 0.3419 - val_loss: 1.0988 - val_accuracy: 0.3265
# Epoch 4/100
# 58/58 [==============================] - 137s 2s/step - loss: 1.0986 - accuracy: 0.3377 - val_loss: 1.0991 - val_accuracy: 0.3265
# Epoch 5/100
# 58/58 [==============================] - 146s 3s/step - loss: 1.0987 - accuracy: 0.3391 - val_loss: 1.0989 - val_accuracy: 0.3265
# Epoch 5: early stopping

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100}%")
# Out:
# 73/73 [==============================] - 15s 204ms/step - loss: 1.0988 - accuracy: 0.3272
# Test Accuracy: 32.71551728248596%
